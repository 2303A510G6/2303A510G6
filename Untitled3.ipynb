# %% [markdown]
# <a href="https://colab.research.google.com/github/2303A510G6/2303A510G6/blob/main/Untitled3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as mpt
people=["kiran", "arun", "vijay", "varun"]
age=[25,30,35,40]
height=[145,151,165,173]
weight=[45,55,65,75]
mpt.scatter(weight, height,color='black')
mpt.title("graph on height and weight")
mpt.xlabel("weight in kgs")
mpt.ylabel("height in meters")
mpt.show()
